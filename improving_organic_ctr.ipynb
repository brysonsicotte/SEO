# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fh = pd.read_csv('fort_hood.csv')

# %%
fh = fh[['query', 'page', 'clicks', 'impressions', 'ctr', 'position', 'title_tag_length', 'meta_description']]

# %%
fh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24539 entries, 0 to 24538
# Data columns (total 8 columns):
# query               24537 non-null object
# page                24539 non-null object
# clicks              24539 non-null object
# impressions         24539 non-null object
# ctr                 24539 non-null object
# position            24539 non-null float64
# title_tag_length    22857 non-null float64
# meta_description    22857 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 1.5+ MB

# %%
fh['clicks'] = fh['clicks'].replace('[,]', '', regex=True).astype('int')
fh['impressions'] = fh['impressions'].replace('[,]', '', regex=True).astype('int')
fh['ctr'] = fh['ctr'].replace('[%,]', '', regex=True).astype('float')

# %%
fh.dropna(inplace=True)

# %%
fh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22855 entries, 0 to 24538
# Data columns (total 8 columns):
# query               22855 non-null object
# page                22855 non-null object
# clicks              22855 non-null int64
# impressions         22855 non-null int64
# ctr                 22855 non-null float64
# position            22855 non-null float64
# title_tag_length    22855 non-null float64
# meta_description    22855 non-null float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.6+ MB

# %%
# filter out row where position not between 3 and 10
fh = fh[(fh['position'] >= 3) & (fh['position'] <= 10)]

# %%
fh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6920 entries, 10 to 24538
# Data columns (total 8 columns):
# query               6920 non-null object
# page                6920 non-null object
# clicks              6920 non-null int64
# impressions         6920 non-null int64
# ctr                 6920 non-null float64
# position            6920 non-null float64
# title_tag_length    6920 non-null float64
# meta_description    6920 non-null float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 486.6+ KB

# %% [markdown]
# ### EDA

# %% [markdown]
# One query-page combination has nearly 200,000 impressions, with a very low, if not 0% CTR.

# %%
plt.scatter(fh['ctr'], fh['impressions'])
plt.xlabel('CTR')
plt.ylabel('Impressions')
# Out:
# Text(0, 0.5, 'Impressions')

# %% [markdown]
# We learn below that the outlier is the combination of the branded query and the home page. This particular query-page combination will often have a very high volume. Due to this, it is not surprising to see a low CTR. If the home page title tag and meta description show clear need for improvement, then optimizing this page would be a good use of time. Otherwise, it is probably better to focus efforts elsewhere.

# %%
fh[fh['impressions'] > 190000]
# Out:
#         query                         page  clicks  impressions   ctr  \
# 10  fort hood  https://www.forthoodfh.com/     662       192051  0.34
#
#     position  title_tag_length  meta_description
# 10       9.1              44.0             268.0

# %% [markdown]
# Let's remove this outlier before we apply k-means to the data.

# %%
fh = fh[fh['impressions'] < 190000]

# %%
plt.scatter(fh['ctr'], fh['impressions'])
plt.xlabel('CTR')
plt.ylabel('Impressions')
# Out:
# Text(0, 0.5, 'Impressions')

# %% [markdown]
# Let's examine the three outliers in the updated plot.

# %%
fh[fh['impressions'] > 10000]
# Out:
#                   query                                               page  \
# 18    fort hood housing  https://www.forthoodfh.com/fort-hood-fort-hood...
# 164             ft hood                        https://www.forthoodfh.com/
# 4344         bonus hood  https://www.forthoodfh.com/fort-hood-fort-hood...
#
#       clicks  impressions   ctr  position  title_tag_length  meta_description
# 18       348        36659  0.95       3.5              51.0              72.0
# 164       37        18610  0.20       9.5              44.0             268.0
# 4344       0        14532  0.00       3.8              67.0              69.0

# %% [markdown]
# - The first is a is a query that frequently pulls up the floor plans page. This page may be a good candidate for improvement.
#
# - The second is a variation of the brand-home page combination from above, and the same logic can be applied.
#
# - The third is an irrelevant search that brings up the floor plans page, and so can be disregarded.

# %% [markdown]
# For the sake generating accurate clusters out of the remaining data points, let's also remove these three data points.

# %%
fh = fh[fh['impressions'] < 10000]

# %%
plt.scatter(fh['ctr'], fh['impressions'])
plt.xlabel('CTR')
plt.ylabel('Impressions')
# Out:
# Text(0, 0.5, 'Impressions')

# %%
from sklearn.cluster import KMeans

# %%
# Create a list of the 'within clusters sum of squares' for each number of clusters
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10)
    kmeans.fit(fh.drop(['query','page'], axis=1))
    wcss.append(kmeans.inertia_)

# %%
# Find the optimal number of clusters using the elbow method
plt.plot(range(1,11), wcss)
plt.title('The Elbow Mehod')
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
# Re-instantiate the kmeans object with 4 clusters
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(fh.drop(['query','page'], axis=1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
fig, ax = plt.subplots(1,1, figsize=(10,6))

ax.scatter(fh['ctr'], fh['impressions'], c=kmeans.labels_, cmap='rainbow')
ax.set_xlabel('CTR')
ax.set_ylabel('Impressions')
# Out:
# Text(0, 0.5, 'Impressions')

# %% [markdown]
# The cluster in the top left of the graph contains the the pages with the greatest opportunity for improvement, followed by the cluster right beneath it. The remaining two clusters are quite noisy, but they contain pages that we don't need to work on, either because there are very few impressions or the CTR is already high.

# %% [markdown]
# ##### Final list of pages to focus on:

# %%
fh['cluster_label'] = kmeans.labels_

# %%
fh.head(10)
# Out:
#                                    query  \
# 15                 fort hood maintenance
# 16                 fort hood maintenance
# 33                 fort hood maintenance
# 35         fort hood housing maintenance
# 42              fort hood housing office
# 52  fort hood family housing maintenance
# 56                  comanche 3 fort hood
# 63                        fhfh fort hood
# 64            fort hood housing villages
# 65                         pershing park
#
#                                                  page  clicks  impressions  \
# 15  https://www.forthoodfh.com/fort-hood-fort-hood...     370         2625
# 16      https://www.forthoodfh.com/resident-resources     365         3865
# 33  https://www.forthoodfh.com/fort-hood-fort-hood...     214         3549
# 35      https://www.forthoodfh.com/resident-resources     202         2135
# 42  https://www.forthoodfh.com/fort-hood-fort-hood...     149         3960
# 52      https://www.forthoodfh.com/resident-resources     115         1244
# 56      https://www.forthoodfh.com/resident-resources     103          808
# 63                        https://www.forthoodfh.com/      98          201
# 64  https://www.forthoodfh.com/fort-hood-fort-hood...      98         1234
# 65  https://www.forthoodfh.com/fort-hood-fort-hood...      97         2686
#
#       ctr  position  title_tag_length  meta_description  cluster_label
# 15  14.10       3.2              51.0              72.0              1
# 16   9.44       3.5              18.0              18.0              1
# 33   6.03       4.5              51.0              72.0              1
# 35   9.46       3.1              18.0              18.0              1
# 42   3.76       3.9              51.0              72.0              1
# 52   9.24       3.5              18.0              18.0              3
# 56  12.75       4.0              18.0              18.0              3
# 63  48.76       3.0              44.0             268.0              0
# 64   7.94       3.1              56.0             201.0              3
# 65   3.61       5.7              67.0              69.0              1

# %% [markdown]
#  Cluster label "1" contains the pages with the most oppourtunity for growth. Cluster label "3" is the next best group. Clusters "0" and "2" can be ignored.

# %%
final_pages = fh[(fh['cluster_label'] == 1) | (fh['cluster_label'] == 3)]

# %%
final_pages.sort_values('cluster_label')
# Out:
#                                       query  \
# 15                    fort hood maintenance
# 1058               fort hood housing office
# 8557                              fort hood
# 9970               fort hood housing office
# 482                       fort hood housing
# 448                fort hood housing office
# 10354                 fort hood maintenance
# 10356                 fort hood maintenance
# 10357                 fort hood maintenance
# 337                           fort hood, tx
# 307                                forthood
# 244               fort hood lawn and garden
# 214                       fort hood website
# 205                fort hood family housing
# 170              fort hood off post housing
# 10368                 fort hood maintenance
# 42                 fort hood housing office
# 97                 fort hood housing office
# 16                    fort hood maintenance
# 65                            pershing park
# 33                    fort hood maintenance
# 35            fort hood housing maintenance
# 8574                              fort hood
# 10126            fort hood housing villages
# 9071             fort hood community center
# 9072             fort hood community center
# 9075             fort hood community center
# 9287   fort hood family housing maintenance
# 9922               fort hood housing number
# 9288   fort hood family housing maintenance
# ...                                     ...
# 1089           fort hood maintenance number
# 1090           fort hood maintenance number
# 1096             fort hood montague housing
# 1119                        fort hood texas
# 1134                    fort mcnair housing
# 819                            fort hood tx
# 394            fort hood housing comanche 3
# 816        fort hood single soldier housing
# 705                   kouma village housing
# 441                fort hood homes for rent
# 460                  kouma community center
# 502          kouma village community center
# 508              off post housing fort hood
# 526               comanche 3 housing office
# 547              fort hood housing villages
# 550                  fort hood rental homes
# 551                        fort hood, texas
# 554                  ft hood family housing
# 557                              hood homes
# 558                             hood houses
# 562                           kouma village
# 568               lawn and garden fort hood
# 612                              fort. hood
# 621                housing around fort hood
# 625                 kouma village fort hood
# 627               liberty village fort hood
# 689                        forthood housing
# 704                   kouma village housing
# 746             comanche 3 community center
# 20379                           play fh.com
#
#                                                     page  clicks  impressions  \
# 15     https://www.forthoodfh.com/fort-hood-fort-hood...     370         2625
# 1058                 https://www.forthoodfh.com/careers/       1         3283
# 8557   https://www.forthoodfh.com/fort-hood-fort-hood...       0         2529
# 9970   https://www.forthoodfh.com/fort-hood-fort-hood...       0         2285
# 482    https://www.forthoodfh.com/fort-hood-fort-hood...       6         2257
# 448    https://www.forthoodfh.com/fort-hood-fort-hood...       7         4783
# 10354  https://www.forthoodfh.com/Apartments/module/a...       0         3196
# 10356  https://www.forthoodfh.com/fort-hood-fort-hood...       0         3351
# 10357  https://www.forthoodfh.com/fort-hood-fort-hood...       0         3247
# 337                          https://www.forthoodfh.com/      12         3216
# 307                          https://www.forthoodfh.com/      14         3008
# 244        https://www.forthoodfh.com/resident-resources      21         2197
# 20379                        https://www.forthoodfh.com/       0          510
#
#          ctr  position  title_tag_length  meta_description  cluster_label
# 15     14.10       3.2              51.0              72.0              1
# 1058    0.03       3.1               7.0               7.0              1
# 8557    0.00       7.2              69.0              71.0              1
# 9970    0.00       3.6              50.0             182.0              1
# 482     0.27       5.3              67.0              69.0              1
# 448     0.15       3.6              56.0             201.0              1
# 10354   0.00       5.2              42.0               0.0              1
# 10356   0.00       5.0              56.0             201.0              1
# 10357   0.00       5.2              51.0             153.0              1
# 337     0.37       9.8              44.0             268.0              1
# 307     0.47       9.3              44.0             268.0              1
# 244     0.96       9.3              18.0              18.0              1
# 214     0.81       8.8              44.0             268.0              1
# 205     0.71       4.1              18.0              18.0              1
# 170     1.47       9.2              44.0             268.0              1
# 10368   0.00       5.1              42.0             223.0              1
# 42      3.76       3.9              51.0              72.0              1
# 97      1.45       3.1              51.0              72.0              1
# 16      9.44       3.5              18.0              18.0              1
# 65      3.61       5.7              67.0              69.0              1
# 33      6.03       4.5              51.0              72.0              1
# 35      9.46       3.1              18.0              18.0              1
# 8574    0.00       6.7              18.0              18.0              3
# 10126   0.00       4.2              50.0             182.0              3
# 9071    0.00       4.3              56.0             201.0              3
# 9072    0.00       4.5              51.0             153.0              3
# 9075    0.00       4.5              42.0             223.0              3
# 9287    0.00       4.2              42.0               0.0              3
# 9922    0.00       3.0               7.0               7.0              3
# 9288    0.00       4.0              56.0             201.0              3
# ...      ...       ...               ...               ...            ...
# 1089    0.12       3.7              56.0             201.0              3
# 1090    0.11       3.9              42.0             223.0              3
# 1096    0.14       3.4              56.0             201.0              3
# 1119    0.26       7.8              42.0             223.0              3
# 1134    0.21       8.2              69.0              71.0              3
# 819     0.37       9.7              56.0             201.0              3
# 394     1.84       6.1              67.0              69.0              3
# 816     0.25       6.1              56.0             201.0              3
# 705     0.60       4.4              18.0              18.0              3
# 441     1.09       9.9              44.0             268.0              3
# 460     0.75       7.7              44.0             268.0              3
# 502     1.06       6.6              44.0             268.0              3
# 508     0.96       8.7              44.0             268.0              3
# 526     0.86       4.4              51.0              72.0              3
# 547     0.46       3.7              18.0              18.0              3
# 550     1.08       7.3              44.0             268.0              3
# 551     0.42       9.9              44.0             268.0              3
# 554     0.47       3.8              51.0              72.0              3
# 557     0.77       6.9              44.0             268.0              3
# 558     0.29       7.4              44.0             268.0              3
# 562     0.51       5.1              51.0              72.0              3
# 568     0.34       9.3              18.0              18.0              3
# 612     0.59       9.6              44.0             268.0              3
# 621     0.49       4.1              44.0             268.0              3
# 625     0.46       4.6              51.0              72.0              3
# 627     0.50       9.4              44.0             268.0              3
# 689     0.71       3.3              51.0              72.0              3
# 704     0.61       4.3              56.0             201.0              3
# 746     0.38       5.9              51.0              72.0              3
# 20379   0.00       7.9              44.0             268.0              3
#
# [198 rows x 9 columns]
